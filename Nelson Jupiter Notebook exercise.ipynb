# %% [markdown]
# # "My Jupiter Notebook on IBM Watson Studio"

# %% [markdown]
# **Nelson Mesonero Núñez**
#
# Conservation biologist

# %% [markdown]
# *I am interested in data science because of the opportunities it offers scientist to reveal insights and patterns in large data sets. AI and machine learing tools can make the difference in scientific studies so, researchers have more tools at their disposal to face the tomorrows' challenges.*

# %% [markdown]
# ### Basic math operation

# %%
(24/2 + 5)
# Out:
# 17.0

# %% [markdown]
# ### Species database of Ecuador
#
# Species | Genus | Family
# --- | --- | ---
# *Bothrops taeniatus* | *Bothrops* | Viperidae
# *Bothrops atrox* | *Bothrops* | Viperidae
# *Bothrocophias microphtalmus* | *Bothrocophias* | Viperidae
# *Bothrocophias hyoprora* | *Bothrocophias* | Viperidae
#
# ### Pictures
# Here's a photo of an adult female of *Bothrops taeniatus*:
#
# Tink(Morona Santiago, EC; Reptiles of Ecuador Book):
# ![alt text](https://www.reptilesofecuador.com/photos/bothrops_taeniatus_adult_female1.jpg "Logo Title Text 1")
#
#
# ### Horizontal rule
#
# Mammals
#
# ---
#
# Birds
#
# ***
#
# Amphibians...
#
# ___
